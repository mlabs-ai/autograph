# %%
from autograph import autograph

builder = autograph.GraphBuilder(0)
builder.add_scale_free_cluster(15, 2)
graph = builder.finalize_graph()

graph.write_to_dot_file("test.dot")
